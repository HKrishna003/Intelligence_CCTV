# %%
# !pip install torch

# %%
import torch

# %%
from IPython.display import Image

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 16003 (delta 21), reused 20 (delta 12), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.66 MiB | 15.19 MiB/s, done.
# Resolving deltas: 100% (10983/10983), done.

# %%
# !unzip /content/drive/MyDrive/traindata.zip
# Out:
# Archive:  /content/drive/MyDrive/traindata.zip
#    creating: traindata/images/
#    creating: traindata/images/train/
#   inflating: traindata/images/train/img 001.jpg
#   inflating: traindata/images/train/img 002.jpg
#   inflating: traindata/images/train/img 003.jpg
#   inflating: traindata/images/train/img 004.jpg
#   inflating: traindata/images/train/img 005.jpg
#   inflating: traindata/images/train/img 006.jpg
#   inflating: traindata/images/train/img 007.jpg
#   inflating: traindata/images/train/img 008.jpg
#   inflating: traindata/images/train/img 009.jpg
#   inflating: traindata/images/train/img 010.jpg
#   inflating: traindata/images/train/img 011.jpg
#   inflating: traindata/images/train/img 012.jpg
#   inflating: traindata/images/train/img 013.jpg
#   inflating: traindata/images/train/img 014.jpg
#   inflating: traindata/images/train/img 015.jpg
#   inflating: traindata/images/train/img 016.jpg
#   inflating: traindata/images/train/img 017.jpg
# ...

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.5/616.5 kB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.4 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 415 --batch 16 --epochs 10 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=415, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/img.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/img.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/img.jpg: 512x640 (no detections), 43.1ms
# Speed: 0.5ms pre-process, 43.1ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
